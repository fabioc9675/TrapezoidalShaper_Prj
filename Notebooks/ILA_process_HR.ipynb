# %% [markdown]
# # Implementacion de las figuras resultado de analizar el ILA

# %% [markdown]
# Implementacion de las figuras del ILA

# %% [markdown]
# ## Carga de librerias

# %%
# Importacion de librerias
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.signal import lfilter, firwin, freqz, resample
from scipy.fft import fft, ifft, fftfreq
from scipy.interpolate import interp1d

# %% [markdown]
# ### Lectura del archivo CSV del ILA

# %%
# Importar el archivo CSV
df = pd.read_csv('iladataAmericio0.csv', delimiter=',')

# Eliminar la primera fila que contiene los nombres de las columnas
df = df.drop(0)

# Convertir los valores a tipo numérico
df = df.apply(pd.to_numeric)

# Obtener los datos de las columnas de interés
x = df['Sample in Buffer']
y1 = df['Sample in Window']
y2 = df['TRIGGER']
#y3 = df['pynq_bd_i/dpp_counter_0_y[31:0]']
#y4 = df['pynq_bd_i/xadc_buffer_0_y[31:0]']
#y5 = df['pynq_bd_i/fir_fab_0_y[31:0]']
#y6 = df['pynq_bd_i/trapz_klm_0_y[31:0]']
y7 = df['pynq_bd_i/xadc_wiz_0_drdy_out']
y8 = df['pynq_bd_i/dpp_counter_0_fifo_o[31:0]']

# Graficar utilizando NumPy
#plt.plot(x, y1, label='Sample in Window')
#plt.plot(x, y2, label='TRIGGER')
#plt.plot(x, y3, label='pynq_bd_i/dpp_counter_0_y[31:0]')
#plt.plot(x, y4, label='pynq_bd_i/xadc_buffer_0_y[31:0]')
#plt.plot(x, y5, label='pynq_bd_i/fir_fab_0_y[31:0]')
#plt.plot(x, y6, label='pynq_bd_i/trapz_klm_0_y[31:0]')
#plt.plot(x, y7, label='pynq_bd_i/xadc_wiz_0_drdy_out')

plt.figure(figsize=(10,2.0))
plt.plot(x/100, y8,color='tab:blue',linewidth=2.5)#, label='pynq_bd_i/dpp_counter_0_fifo_o[31:0]')
plt.fill_between(x/100, y8, color='skyblue', alpha=0.6)

# Configurar la leyenda y las etiquetas de los ejes
#plt.title("Americio")
plt.legend()
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.xlim([0,500])
plt.ylim([-10,230])
plt.grid(True)

# Mostrar el gráfico
#plt.show()

plt.savefig("output/AmeriEnergy.pdf", format="pdf", bbox_inches="tight")
# Out:
# C:\Users\fabio\AppData\Local\Temp\ipykernel_5780\886652423.py:36: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Importar el archivo CSV
df = pd.read_csv('iladataTorio0.csv', delimiter=',')

# Eliminar la primera fila que contiene los nombres de las columnas
df = df.drop(0)

# Convertir los valores a tipo numérico
df = df.apply(pd.to_numeric)

# Obtener los datos de las columnas de interés
x = df['Sample in Buffer']
y1 = df['Sample in Window']
y2 = df['TRIGGER']
#y3 = df['pynq_bd_i/dpp_counter_0_y[31:0]']
#y4 = df['pynq_bd_i/xadc_buffer_0_y[31:0]']
#y5 = df['pynq_bd_i/fir_fab_0_y[31:0]']
#y6 = df['pynq_bd_i/trapz_klm_0_y[31:0]']
y7 = df['pynq_bd_i/xadc_wiz_0_drdy_out']
y8 = df['pynq_bd_i/dpp_counter_0_fifo_o[31:0]']

# Graficar utilizando NumPy
#plt.plot(x, y1, label='Sample in Window')
#plt.plot(x, y2, label='TRIGGER')
#plt.plot(x, y3, label='pynq_bd_i/dpp_counter_0_y[31:0]')
#plt.plot(x, y4, label='pynq_bd_i/xadc_buffer_0_y[31:0]')
#plt.plot(x, y5, label='pynq_bd_i/fir_fab_0_y[31:0]')
#plt.plot(x, y6, label='pynq_bd_i/trapz_klm_0_y[31:0]')
#plt.plot(x, y7, label='pynq_bd_i/xadc_wiz_0_drdy_out')

plt.figure(figsize=(10,2.0))
plt.plot(x/100, y8,color='tab:blue',linewidth=2.5)#, label='pynq_bd_i/dpp_counter_0_fifo_o[31:0]')
plt.fill_between(x/100, y8, color='skyblue', alpha=0.6)

# Configurar la leyenda y las etiquetas de los ejes
#plt.title("Torio")
plt.legend()
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.xlim([0,500])
plt.ylim([-10,230])
plt.grid(True)

# Mostrar el gráfico
#plt.show()

plt.savefig("output/TorioEnergy.pdf", format="pdf", bbox_inches="tight")
# Out:
# C:\Users\fabio\AppData\Local\Temp\ipykernel_5780\705537658.py:36: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ## Pruebas a 2 horas

# %%
# Importar el archivo CSV
df = pd.read_csv('iladataamehr2h.csv', delimiter=',')

# Eliminar la primera fila que contiene los nombres de las columnas
df = df.drop(0)

# Convertir los valores a tipo numérico
df = df.apply(pd.to_numeric)

# Obtener los datos de las columnas de interés
x = df['Sample in Buffer']
y1 = df['Sample in Window']
y2 = df['TRIGGER']
#y3 = df['pynq_bd_i/dpp_counter_0_y[31:0]']
#y4 = df['pynq_bd_i/xadc_buffer_0_y[31:0]']
#y5 = df['pynq_bd_i/fir_fab_0_y[31:0]']
#y6 = df['pynq_bd_i/trapz_klm_0_y[31:0]']
y7 = df['pynq_bd_i/xadc_wiz_0_drdy_out']
y8 = df['pynq_bd_i/dpp_counter_0_fifo_o[31:0]']

# Graficar utilizando NumPy
#plt.plot(x, y1, label='Sample in Window')
#plt.plot(x, y2, label='TRIGGER')
#plt.plot(x, y3, label='pynq_bd_i/dpp_counter_0_y[31:0]')
#plt.plot(x, y4, label='pynq_bd_i/xadc_buffer_0_y[31:0]')
#plt.plot(x, y5, label='pynq_bd_i/fir_fab_0_y[31:0]')
#plt.plot(x, y6, label='pynq_bd_i/trapz_klm_0_y[31:0]')
#plt.plot(x, y7, label='pynq_bd_i/xadc_wiz_0_drdy_out')

plt.figure(figsize=(10,2.0))
plt.plot(x/100, y8,color='tab:blue',linewidth=2.5)#, label='pynq_bd_i/dpp_counter_0_fifo_o[31:0]')
plt.fill_between(x/100, y8, color='skyblue', alpha=0.6)

# Configurar la leyenda y las etiquetas de los ejes
#plt.title("Americio")
plt.legend()
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.xlim([0,500])
#plt.ylim([-10,4200])
plt.grid(True)

# Mostrar el gráfico
#plt.show()

#plt.savefig("output/AmeriEnergy_2h.pdf", format="pdf", bbox_inches="tight")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Importar el archivo CSV
df = pd.read_csv('iladatatorhr4h.csv', delimiter=',')

# Eliminar la primera fila que contiene los nombres de las columnas
df = df.drop(0)

# Convertir los valores a tipo numérico
df = df.apply(pd.to_numeric)

# Obtener los datos de las columnas de interés
x = df['Sample in Buffer']
y1 = df['Sample in Window']
y2 = df['TRIGGER']
#y3 = df['pynq_bd_i/dpp_counter_0_y[31:0]']
#y4 = df['pynq_bd_i/xadc_buffer_0_y[31:0]']
#y5 = df['pynq_bd_i/fir_fab_0_y[31:0]']
#y6 = df['pynq_bd_i/trapz_klm_0_y[31:0]']
y7 = df['pynq_bd_i/xadc_wiz_0_drdy_out']
y8 = df['pynq_bd_i/dpp_counter_0_fifo_o[31:0]']

# Graficar utilizando NumPy
#plt.plot(x, y1, label='Sample in Window')
#plt.plot(x, y2, label='TRIGGER')
#plt.plot(x, y3, label='pynq_bd_i/dpp_counter_0_y[31:0]')
#plt.plot(x, y4, label='pynq_bd_i/xadc_buffer_0_y[31:0]')
#plt.plot(x, y5, label='pynq_bd_i/fir_fab_0_y[31:0]')
#plt.plot(x, y6, label='pynq_bd_i/trapz_klm_0_y[31:0]')
#plt.plot(x, y7, label='pynq_bd_i/xadc_wiz_0_drdy_out')

plt.figure(figsize=(10,2.0))
plt.plot(x/100, y8,color='tab:blue',linewidth=2.5)#, label='pynq_bd_i/dpp_counter_0_fifo_o[31:0]')
plt.fill_between(x/100, y8, color='skyblue', alpha=0.6)

# Configurar la leyenda y las etiquetas de los ejes
#plt.title("Americio")
plt.legend()
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.xlim([0,500])
#plt.ylim([-10,4200])
plt.grid(True)

# Mostrar el gráfico
#plt.show()

#plt.savefig("output/TorioEnergy_2h.pdf", format="pdf", bbox_inches="tight")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Importar el archivo CSV
df = pd.read_csv('iladatabac12h.csv', delimiter=',')

# Eliminar la primera fila que contiene los nombres de las columnas
df = df.drop(0)

# Convertir los valores a tipo numérico
df = df.apply(pd.to_numeric)

# Obtener los datos de las columnas de interés
x = df['Sample in Buffer']
y1 = df['Sample in Window']
y2 = df['TRIGGER']
#y3 = df['pynq_bd_i/dpp_counter_0_y[31:0]']
#y4 = df['pynq_bd_i/xadc_buffer_0_y[31:0]']
#y5 = df['pynq_bd_i/fir_fab_0_y[31:0]']
#y6 = df['pynq_bd_i/trapz_klm_0_y[31:0]']
y7 = df['pynq_bd_i/xadc_wiz_0_drdy_out']
y8 = df['pynq_bd_i/dpp_counter_0_fifo_o[31:0]']

# Graficar utilizando NumPy
#plt.plot(x, y1, label='Sample in Window')
#plt.plot(x, y2, label='TRIGGER')
#plt.plot(x, y3, label='pynq_bd_i/dpp_counter_0_y[31:0]')
#plt.plot(x, y4, label='pynq_bd_i/xadc_buffer_0_y[31:0]')
#plt.plot(x, y5, label='pynq_bd_i/fir_fab_0_y[31:0]')
#plt.plot(x, y6, label='pynq_bd_i/trapz_klm_0_y[31:0]')
#plt.plot(x, y7, label='pynq_bd_i/xadc_wiz_0_drdy_out')

plt.figure(figsize=(10,2.0))
plt.plot(x/100, y8,color='tab:blue',linewidth=2.5)#, label='pynq_bd_i/dpp_counter_0_fifo_o[31:0]')
plt.fill_between(x/100, y8, color='skyblue', alpha=0.6)

# Configurar la leyenda y las etiquetas de los ejes
#plt.title("Americio")
plt.legend()
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.xlim([0,500])
#plt.ylim([-10,4200])
plt.grid(True)

# Mostrar el gráfico
#plt.show()

#plt.savefig("output/BackEnergy_2h.pdf", format="pdf", bbox_inches="tight")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Procesamiento de senal del centellador

# %%
# Importar el archivo CSV
df = pd.read_csv('ilascintTor03.csv', delimiter=',')

# Eliminar la primera fila que contiene los nombres de las columnas
df = df.drop(0)

# Convertir los valores a tipo numérico
df = df.apply(pd.to_numeric)

# Obtener los datos de las columnas de interés
x = df['Sample in Buffer']
y1 = df['Sample in Window']
y2 = df['TRIGGER']
#y3 = df['pynq_bd_i/dpp_counter_0_y[31:0]']
#y4 = df['pynq_bd_i/xadc_buffer_0_y[31:0]']
#y5 = df['pynq_bd_i/fir_fab_0_y[31:0]']
#y6 = df['pynq_bd_i/trapz_klm_0_y[31:0]']
y7 = df['pynq_bd_i/xadc_wiz_0_drdy_out']
y8 = df['pynq_bd_i/dpp_counter_0_fifo_o[31:0]']
y9 = df['pynq_bd_i/dpp_counter_0_y[31:0]']

# Graficar utilizando NumPy
#plt.plot(x, y1, label='Sample in Window')
#plt.plot(x, y2, label='TRIGGER')
#plt.plot(x, y3, label='pynq_bd_i/dpp_counter_0_y[31:0]')
#plt.plot(x, y4, label='pynq_bd_i/xadc_buffer_0_y[31:0]')
#plt.plot(x, y5, label='pynq_bd_i/fir_fab_0_y[31:0]')
#plt.plot(x, y6, label='pynq_bd_i/trapz_klm_0_y[31:0]')
#plt.plot(x, y7, label='pynq_bd_i/xadc_wiz_0_drdy_out')

plt.figure(figsize=(10,2.0))
plt.plot(x/100, y8,color='tab:blue',linewidth=1.0)#, label='pynq_bd_i/dpp_counter_0_fifo_o[31:0]')
plt.fill_between(x/100, y8, color='skyblue', alpha=0.6)

# Configurar la leyenda y las etiquetas de los ejes
#plt.title("Americio")
plt.legend()
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.xlim([0,500])
#plt.ylim([-10,4200])
plt.grid(True)

# Mostrar el gráfico
#plt.show()

#plt.savefig("output/TorEnergy_scint.pdf", format="pdf", bbox_inches="tight")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Importar el archivo CSV
df = pd.read_csv('ilascintTor05.csv', delimiter=',')

# Eliminar la primera fila que contiene los nombres de las columnas
df = df.drop(0)

# Convertir los valores a tipo numérico
df = df.apply(pd.to_numeric)

# Obtener los datos de las columnas de interés
x = df['Sample in Buffer']
y1 = df['Sample in Window']
y2 = df['TRIGGER']
#y3 = df['pynq_bd_i/dpp_counter_0_y[31:0]']
#y4 = df['pynq_bd_i/xadc_buffer_0_y[31:0]']
#y5 = df['pynq_bd_i/fir_fab_0_y[31:0]']
#y6 = df['pynq_bd_i/trapz_klm_0_y[31:0]']
y7 = df['pynq_bd_i/xadc_wiz_0_drdy_out']
y8 = df['pynq_bd_i/dpp_counter_0_fifo_o[31:0]']
y9 = df['pynq_bd_i/dpp_counter_0_y[31:0]']

# Graficar utilizando NumPy
#plt.plot(x, y1, label='Sample in Window')
#plt.plot(x, y2, label='TRIGGER')
#plt.plot(x, y3, label='pynq_bd_i/dpp_counter_0_y[31:0]')
#plt.plot(x, y4, label='pynq_bd_i/xadc_buffer_0_y[31:0]')
#plt.plot(x, y5, label='pynq_bd_i/fir_fab_0_y[31:0]')
#plt.plot(x, y6, label='pynq_bd_i/trapz_klm_0_y[31:0]')
#plt.plot(x, y7, label='pynq_bd_i/xadc_wiz_0_drdy_out')


# Creamos un array booleano que indica dónde los datos son mayores que 100 en el rango dado
condicion = (y8[16000:100000] > 50)

# Cambiamos los valores mayores que 100 a 0 en el rango dado
y8[16000:100000][condicion] = 0


plt.figure(figsize=(10,2.0))
plt.plot(x/100, y8,color='tab:blue',linewidth=1.0)#, label='pynq_bd_i/dpp_counter_0_fifo_o[31:0]')
plt.fill_between(x/100, y8, color='skyblue', alpha=0.6)

# Configurar la leyenda y las etiquetas de los ejes
#plt.title("Americio")
plt.legend()
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.xlim([0,500])
#plt.ylim([-10,4200])
plt.grid(True)

# Mostrar el gráfico
#plt.show()

plt.savefig("output/TorEnergy_scint02.pdf", format="pdf", bbox_inches="tight")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Pruebas 19 de Abril 2024

# %%
# Importar el archivo CSV
df = pd.read_csv('ilascintTor11.csv', delimiter=',')

# Eliminar la primera fila que contiene los nombres de las columnas
df = df.drop(0)

# Convertir los valores a tipo numérico
df = df.apply(pd.to_numeric)

# Obtener los datos de las columnas de interés
x = df['Sample in Buffer']
y1 = df['Sample in Window']
y2 = df['TRIGGER']
#y3 = df['pynq_bd_i/dpp_counter_0_y[31:0]']
#y4 = df['pynq_bd_i/xadc_buffer_0_y[31:0]']
#y5 = df['pynq_bd_i/fir_fab_0_y[31:0]']
#y6 = df['pynq_bd_i/trapz_klm_0_y[31:0]']
y7 = df['pynq_bd_i/xadc_wiz_0_drdy_out']
y8 = df['pynq_bd_i/dpp_counter_0_fifo_o[31:0]']
y9 = df['pynq_bd_i/dpp_counter_0_y[31:0]']

# Graficar utilizando NumPy
#plt.plot(x, y1, label='Sample in Window')
#plt.plot(x, y2, label='TRIGGER')
#plt.plot(x, y3, label='pynq_bd_i/dpp_counter_0_y[31:0]')
#plt.plot(x, y4, label='pynq_bd_i/xadc_buffer_0_y[31:0]')
#plt.plot(x, y5, label='pynq_bd_i/fir_fab_0_y[31:0]')
#plt.plot(x, y6, label='pynq_bd_i/trapz_klm_0_y[31:0]')
#plt.plot(x, y7, label='pynq_bd_i/xadc_wiz_0_drdy_out')


plt.figure(figsize=(10,2.0))
plt.plot(x/100, y8,color='tab:blue',linewidth=1.0)#, label='pynq_bd_i/dpp_counter_0_fifo_o[31:0]')
plt.fill_between(x/100, y8, color='skyblue', alpha=0.6)

# Configurar la leyenda y las etiquetas de los ejes
#plt.title("Americio")
plt.legend()
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.xlim([0,500])
#plt.ylim([-10,4200])
plt.grid(True)

# Mostrar el gráfico
#plt.show()

#plt.savefig("output/TorEnergy_scint02.pdf", format="pdf", bbox_inches="tight")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Importar el archivo CSV
df = pd.read_csv('ilascintAme12.csv', delimiter=',')

# Eliminar la primera fila que contiene los nombres de las columnas
df = df.drop(0)

# Convertir los valores a tipo numérico
df = df.apply(pd.to_numeric)

# Obtener los datos de las columnas de interés
x = df['Sample in Buffer']
y1 = df['Sample in Window']
y2 = df['TRIGGER']
#y3 = df['pynq_bd_i/dpp_counter_0_y[31:0]']
#y4 = df['pynq_bd_i/xadc_buffer_0_y[31:0]']
#y5 = df['pynq_bd_i/fir_fab_0_y[31:0]']
#y6 = df['pynq_bd_i/trapz_klm_0_y[31:0]']
y7 = df['pynq_bd_i/xadc_wiz_0_drdy_out']
y8 = df['pynq_bd_i/dpp_counter_0_fifo_o[31:0]']
y9 = df['pynq_bd_i/dpp_counter_0_y[31:0]']

# Graficar utilizando NumPy
#plt.plot(x, y1, label='Sample in Window')
#plt.plot(x, y2, label='TRIGGER')
#plt.plot(x, y3, label='pynq_bd_i/dpp_counter_0_y[31:0]')
#plt.plot(x, y4, label='pynq_bd_i/xadc_buffer_0_y[31:0]')
#plt.plot(x, y5, label='pynq_bd_i/fir_fab_0_y[31:0]')
#plt.plot(x, y6, label='pynq_bd_i/trapz_klm_0_y[31:0]')
#plt.plot(x, y7, label='pynq_bd_i/xadc_wiz_0_drdy_out')


plt.figure(figsize=(10,2.0))
plt.plot(x/100, y8,color='tab:blue',linewidth=1.0)#, label='pynq_bd_i/dpp_counter_0_fifo_o[31:0]')
plt.fill_between(x/100, y8, color='skyblue', alpha=0.6)

# Configurar la leyenda y las etiquetas de los ejes
#plt.title("Americio")
plt.legend()
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.xlim([0,500])
#plt.ylim([-10,4200])
plt.grid(True)

# Mostrar el gráfico
#plt.show()

#plt.savefig("output/TorEnergy_scint02.pdf", format="pdf", bbox_inches="tight")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Otros espectros

# %%
# Importar el archivo CSV
df = pd.read_csv('ilascintAme20.csv', delimiter=',')

# Eliminar la primera fila que contiene los nombres de las columnas
df = df.drop(0)

# Convertir los valores a tipo numérico
df = df.apply(pd.to_numeric)

# Obtener los datos de las columnas de interés
x = df['Sample in Buffer']
y1 = df['Sample in Window']
y2 = df['TRIGGER']
#y3 = df['pynq_bd_i/dpp_counter_0_y[31:0]']
#y4 = df['pynq_bd_i/xadc_buffer_0_y[31:0]']
#y5 = df['pynq_bd_i/fir_fab_0_y[31:0]']
#y6 = df['pynq_bd_i/trapz_klm_0_y[31:0]']
y7 = df['pynq_bd_i/xadc_wiz_0_drdy_out']
y8 = df['pynq_bd_i/dpp_counter_0_fifo_o[31:0]']
y9 = df['pynq_bd_i/dpp_counter_0_y[31:0]']

# Graficar utilizando NumPy
#plt.plot(x, y1, label='Sample in Window')
#plt.plot(x, y2, label='TRIGGER')
#plt.plot(x, y3, label='pynq_bd_i/dpp_counter_0_y[31:0]')
#plt.plot(x, y4, label='pynq_bd_i/xadc_buffer_0_y[31:0]')
#plt.plot(x, y5, label='pynq_bd_i/fir_fab_0_y[31:0]')
#plt.plot(x, y6, label='pynq_bd_i/trapz_klm_0_y[31:0]')
#plt.plot(x, y7, label='pynq_bd_i/xadc_wiz_0_drdy_out')


plt.figure(figsize=(10,2.0))
plt.plot(x/100, y8,color='tab:blue',linewidth=1.0)#, label='pynq_bd_i/dpp_counter_0_fifo_o[31:0]')
plt.fill_between(x/100, y8, color='skyblue', alpha=0.6)

# Configurar la leyenda y las etiquetas de los ejes
#plt.title("Americio")
plt.legend()
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.xlim([0,500])
#plt.ylim([-10,4200])
plt.grid(True)

# Mostrar el gráfico
#plt.show()

#plt.savefig("output/TorEnergy_scint02.pdf", format="pdf", bbox_inches="tight")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Importar el archivo CSV
df = pd.read_csv('ilascintTor21.csv', delimiter=',')

# Eliminar la primera fila que contiene los nombres de las columnas
df = df.drop(0)

# Convertir los valores a tipo numérico
df = df.apply(pd.to_numeric)

# Obtener los datos de las columnas de interés
x = df['Sample in Buffer']
y1 = df['Sample in Window']
y2 = df['TRIGGER']
#y3 = df['pynq_bd_i/dpp_counter_0_y[31:0]']
#y4 = df['pynq_bd_i/xadc_buffer_0_y[31:0]']
#y5 = df['pynq_bd_i/fir_fab_0_y[31:0]']
#y6 = df['pynq_bd_i/trapz_klm_0_y[31:0]']
y7 = df['pynq_bd_i/xadc_wiz_0_drdy_out']
y8 = df['pynq_bd_i/dpp_counter_0_fifo_o[31:0]']
y9 = df['pynq_bd_i/dpp_counter_0_y[31:0]']

# Graficar utilizando NumPy
#plt.plot(x, y1, label='Sample in Window')
#plt.plot(x, y2, label='TRIGGER')
#plt.plot(x, y3, label='pynq_bd_i/dpp_counter_0_y[31:0]')
#plt.plot(x, y4, label='pynq_bd_i/xadc_buffer_0_y[31:0]')
#plt.plot(x, y5, label='pynq_bd_i/fir_fab_0_y[31:0]')
#plt.plot(x, y6, label='pynq_bd_i/trapz_klm_0_y[31:0]')
#plt.plot(x, y7, label='pynq_bd_i/xadc_wiz_0_drdy_out')


plt.figure(figsize=(10,2.0))
plt.plot(x/100, y8,color='tab:blue',linewidth=1.0)#, label='pynq_bd_i/dpp_counter_0_fifo_o[31:0]')
plt.fill_between(x/100, y8, color='skyblue', alpha=0.6)

# Configurar la leyenda y las etiquetas de los ejes
#plt.title("Americio")
plt.legend()
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.xlim([0,500])
#plt.ylim([-10,4200])
plt.grid(True)

# Mostrar el gráfico
#plt.show()

#plt.savefig("output/TorEnergy_scint02.pdf", format="pdf", bbox_inches="tight")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Importar el archivo CSV
df = pd.read_csv('ilascintBack20.csv', delimiter=',')

# Eliminar la primera fila que contiene los nombres de las columnas
df = df.drop(0)

# Convertir los valores a tipo numérico
df = df.apply(pd.to_numeric)

# Obtener los datos de las columnas de interés
x = df['Sample in Buffer']
y1 = df['Sample in Window']
y2 = df['TRIGGER']
#y3 = df['pynq_bd_i/dpp_counter_0_y[31:0]']
#y4 = df['pynq_bd_i/xadc_buffer_0_y[31:0]']
#y5 = df['pynq_bd_i/fir_fab_0_y[31:0]']
#y6 = df['pynq_bd_i/trapz_klm_0_y[31:0]']
y7 = df['pynq_bd_i/xadc_wiz_0_drdy_out']
y8 = df['pynq_bd_i/dpp_counter_0_fifo_o[31:0]']
y9 = df['pynq_bd_i/dpp_counter_0_y[31:0]']

# Graficar utilizando NumPy
#plt.plot(x, y1, label='Sample in Window')
#plt.plot(x, y2, label='TRIGGER')
#plt.plot(x, y3, label='pynq_bd_i/dpp_counter_0_y[31:0]')
#plt.plot(x, y4, label='pynq_bd_i/xadc_buffer_0_y[31:0]')
#plt.plot(x, y5, label='pynq_bd_i/fir_fab_0_y[31:0]')
#plt.plot(x, y6, label='pynq_bd_i/trapz_klm_0_y[31:0]')
#plt.plot(x, y7, label='pynq_bd_i/xadc_wiz_0_drdy_out')


plt.figure(figsize=(10,2.0))
plt.plot(x/100, y8,color='tab:blue',linewidth=1.0)#, label='pynq_bd_i/dpp_counter_0_fifo_o[31:0]')
plt.fill_between(x/100, y8, color='skyblue', alpha=0.6)

# Configurar la leyenda y las etiquetas de los ejes
#plt.title("Americio")
plt.legend()
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.xlim([0,500])
#plt.ylim([-10,4200])
plt.grid(True)

# Mostrar el gráfico
#plt.show()

#plt.savefig("output/TorEnergy_scint02.pdf", format="pdf", bbox_inches="tight")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Pruebas de generacion de distribucion

# %%
# Importar el archivo CSV
df = pd.read_csv('hist_signal_com_04.csv', delimiter=',')

# Eliminar la primera fila que contiene los nombres de las columnas
#df = df.drop(0)

# Convertir los valores a tipo numérico
df = df.apply(pd.to_numeric)

# Obtener los datos de las columnas de interés
#x = df['Sample in Buffer']
y1 = df.to_numpy()[:,0]
#y2 = df['TRIGGER']
#y3 = df['pynq_bd_i/dpp_counter_0_y[31:0]']
#y4 = df['pynq_bd_i/xadc_buffer_0_y[31:0]']
#y5 = df['pynq_bd_i/fir_fab_0_y[31:0]']
#y6 = df['pynq_bd_i/trapz_klm_0_y[31:0]']
#y7 = df['pynq_bd_i/xadc_wiz_0_drdy_out']
#y8 = df['pynq_bd_i/dpp_counter_0_fifo_o[31:0]']
#y9 = df['pynq_bd_i/dpp_counter_0_y[31:0]']
x = np.arange(0,len(y1), 1)

# Graficar utilizando NumPy
#plt.plot(x, y1, label='Sample in Window')
#plt.plot(x, y2, label='TRIGGER')
#plt.plot(x, y3, label='pynq_bd_i/dpp_counter_0_y[31:0]')
#plt.plot(x, y4, label='pynq_bd_i/xadc_buffer_0_y[31:0]')
#plt.plot(x, y5, label='pynq_bd_i/fir_fab_0_y[31:0]')
#plt.plot(x, y6, label='pynq_bd_i/trapz_klm_0_y[31:0]')
#plt.plot(x, y7, label='pynq_bd_i/xadc_wiz_0_drdy_out')


plt.figure(figsize=(10,2.0))
plt.plot(1.5*x/100 + 2, y1,color='tab:blue',linewidth=1.0)#, label='pynq_bd_i/dpp_counter_0_fifo_o[31:0]')
plt.fill_between(1.5*x/100 + 2, y1, color='skyblue', alpha=0.6)

# Configurar la leyenda y las etiquetas de los ejes
#plt.title("Americio")
#plt.legend()
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.xlim([5,25])
#plt.ylim([-10,4200])
plt.grid(True)

# Mostrar el gráfico
#plt.show()

plt.savefig("output/RealHistogram.pdf", format="pdf", bbox_inches="tight")

# %%
# --- Cargar el vector desde el archivo CSV ---
filename = "alturas.csv"
loaded_df = pd.read_csv(filename)  # Leer el archivo CSV
loaded_vector = loaded_df["Values"].values  # Convertir la columna de nuevo a un array
print("Vector cargado desde el CSV:")
# plt.figure(figsize=(10,2.0))
#plt.plot(loaded_vector)

# Calcular la densidad (PDF) usando bins del histograma
bins = 800
count, bins = np.histogram(loaded_vector, bins=bins, density=True)
x = bins[:-1]  # Obtener los bordes izquierdos de los bins
y1 = 30*count  # Usar los valores de densidad del histograma

# Graficar línea con área sombreada
plt.figure(figsize=(10, 2.0))
plt.plot(x, y1, color='tab:blue', linewidth=1.0)
plt.fill_between(x, y1, color='skyblue', alpha=0.6)

# Configurar la leyenda y las etiquetas de los ejes
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.xlim([5, 25])
plt.grid(True)

# Mostrar el gráfico
# plt.show()

plt.savefig("output/SimuHistogram.pdf", format="pdf", bbox_inches="tight")
# Out:
# Vector cargado desde el CSV:

# %%
# --- Cargar el vector desde el archivo CSV ---
filename = "./scriptsICTP/fifoSampleTrace_02.csv"
loaded_df = pd.read_csv(filename)  # Leer el archivo CSV
loaded_vector_ref = loaded_df.to_numpy()[:,1]  # Convertir la columna de nuevo a un array
print("Vector cargado desde el CSV:")
# plt.figure(figsize=(10,2.0))
#plt.plot(loaded_vector)

# Calcular la densidad (PDF) usando bins del histograma
bins = 200
count_ref, bins_ref = np.histogram(loaded_vector_ref, bins=bins, density=False, range=(200,1500))

x1 = bins_ref[:-1]  # Obtener los bordes izquierdos de los bins
y1 = count_ref  # Usar los valores de densidad del histograma


filename = "./scriptsICTP/fifoInputTrace_01.csv"
loaded_df = pd.read_csv(filename)  # Leer el archivo CSV
loaded_vector = loaded_df.to_numpy()[:,1]   # Convertir la columna de nuevo a un array
print("Vector cargado desde el CSV:")
# plt.figure(figsize=(10,2.0))
#plt.plot(loaded_vector)

# Calcular la densidad (PDF) usando bins del histograma
bins = 200
count_dat, bins_dat = np.histogram(loaded_vector, bins=bins, density=False, range=(200,1500))


x2 = bins_dat[:-1]  # Obtener los bordes izquierdos de los bins
y2 = count_dat  # Usar los valores de densidad del histograma

# Graficar línea con área sombreada
plt.figure(figsize=(10, 3.0))
#plt.grid(True)
plt.bar(x1, y1, width=1300/200, color='tab:blue', label="Reference")
#plt.plot(x1, y1, color='tab:orange', linewidth=1.0,)
plt.bar(x2, y2, width=1300/200, color='tab:orange', label="Real")
#plt.plot(x2, y2, color='tab:blue', linewidth=1.0, label="Real")
#plt.fill_between(x2, y2, color='skyblue', alpha=0.6)

# Configurar la leyenda y las etiquetas de los ejes
plt.legend()
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.xlim([200, 1500])
plt.ylim([0, 200])


# Mostrar el gráfico
# plt.show()

plt.savefig("output/CoHistogram.pdf", format="pdf", bbox_inches="tight")
# Out:
# Vector cargado desde el CSV:
# Vector cargado desde el CSV:

# %%
# Importar el archivo CSV
df = pd.read_csv('hist_signal_com_04.csv', delimiter=',')

# Convertir los valores a tipo numérico
df = df.apply(pd.to_numeric)

# Obtener los datos de las columnas de interés
#x = df['Sample in Buffer']
y1 = df.to_numpy()[:,0]

x1 = np.arange(0,len(y1), 1)


# --- Cargar el vector desde el archivo CSV ---
filename = "alturas.csv"
loaded_df = pd.read_csv(filename)  # Leer el archivo CSV
loaded_vector = loaded_df["Values"].values  # Convertir la columna de nuevo a un array
print("Vector cargado desde el CSV:")
# plt.figure(figsize=(10,2.0))
#plt.plot(loaded_vector)

# Calcular la densidad (PDF) usando bins del histograma
bins = 800
count, bins = np.histogram(loaded_vector, bins=bins, density=True)
x2 = bins[:-1]  # Obtener los bordes izquierdos de los bins
y2 = 35*count  # Usar los valores de densidad del histograma


# Graficar línea con área sombreada
plt.figure(figsize=(10, 3.0))
#plt.grid(True)
plt.bar(x2, y2, width=25/150, color='tab:blue', label="Simulated")
#plt.plot(x1, y1, color='tab:orange', linewidth=1.0,)
plt.bar(1.5*x1/100 + 2, y1, width=25/150, color='tab:orange', label="Measured")
#plt.plot(x2, y2, color='tab:blue', linewidth=1.0, label="Real")
#plt.fill_between(x2, y2, color='skyblue', alpha=0.6)

# Configurar la leyenda y las etiquetas de los ejes
plt.legend()
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.xlim([0, 35])
#plt.ylim([0, 200])


# Mostrar el gráfico
# plt.show()

plt.savefig("output/CoHistogram_sim.pdf", format="pdf", bbox_inches="tight")
# Out:
# Vector cargado desde el CSV:

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Importar el archivo CSV
df = pd.read_csv('amer_spect.csv', delimiter=',')

# Convertir los valores a tipo numérico
df = df.apply(pd.to_numeric)

# Obtener los datos de las columnas de interés
x1 = df.to_numpy()[:,0]
y1 = df.to_numpy()[:,1]

# Crear un DataFrame temporal para agrupar y obtener el máximo
temp_df = pd.DataFrame({'x1': x1, 'y1': y1})
max_df = temp_df.groupby('x1', as_index=False).max()

# Actualizar x1 y y1 con los valores agrupados
x1 = max_df['x1'].to_numpy()
y1 = max_df['y1'].to_numpy()

# Importar el archivo CSV
df = pd.read_csv('ilascintAme12.csv', delimiter=',')

# Eliminar la primera fila que contiene los nombres de las columnas
df = df.drop(0)

# Convertir los valores a tipo numérico
df = df.apply(pd.to_numeric)

# Obtener los datos de las columnas de interés
x2 = df['Sample in Buffer']
y2 = df['pynq_bd_i/dpp_counter_0_fifo_o[31:0]']

# Evaluar solo cada 10 datos
x2 = x2[::10]
y2 = y2[::10]

# Graficar línea con área sombreada
plt.figure(figsize=(10, 3.0))
plt.bar(x1-10, y1, width=170/150, color='tab:blue', label="Reference")
plt.bar(x2/370+5, 2*y2, width=170/150, color='tab:orange', label="Real")

# Configurar la leyenda y las etiquetas de los ejes
plt.legend()
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.xlim([0, 125])

# Mostrar el gráfico


# Guardar el gráfico
plt.savefig("output/AmHistogram_sim.pdf", format="pdf", bbox_inches="tight")

# %%
plt.plot(max_df['x1'], max_df['y1'])
